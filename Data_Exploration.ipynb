# %% [markdown]
# Importing all libraies

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# Displaying the full dataset as **Startup_DF**

# %%
Startup_DF = pd.read_csv('Data/50_Startups.csv')
Startup_DF
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %% [markdown]
# Displaying all of the columns so i can select the columns i need

# %%
Startup_DF.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %% [markdown]
# Selecting all the columns i need and splitting the data into into a subset called **Startup_SS_st_Pro** i chose this to see if profit in new york is above 100000

# %%
Startup_SS_st_Pro = Startup_DF[[  'State', 'Profit']]
Startup_SS_st_Pro
# Out:
#          State     Profit
# 0     New York  192261.83
# 1   California  191792.06
# 2      Florida  191050.39
# 3     New York  182901.99
# 4      Florida  166187.94
# 5     New York  156991.12
# 6   California  156122.51
# 7      Florida  155752.60
# 8     New York  152211.77
# 9   California  149759.96
# 10     Florida  146121.95
# 11  California  144259.40
# 12     Florida  141585.52
# 13  California  134307.35
# 14     Florida  132602.65
# 15    New York  129917.04
# 16  California  126992.93
# 17    New York  125370.37
# 18     Florida  124266.90
# 19    New York  122776.86
# 20  California  118474.03
# 21    New York  111313.02
# 22     Florida  110352.25
# 23     Florida  108733.99
# 24    New York  108552.04
# 25  California  107404.34
# 26     Florida  105733.54
# 27    New York  105008.31
# 28     Florida  103282.38
# 29    New York  101004.64
# 30     Florida   99937.59
# 31    New York   97483.56
# 32  California   97427.84
# 33     Florida   96778.92
# ...

# %% [markdown]
# I will only show table values containing new york

# %%
# only show tables with state = New York
Startup_SS_Ny = Startup_SS_st_Pro[Startup_SS_st_Pro['State'] == 'New York']
Startup_SS_Ny
# Out:
#        State     Profit
# 0   New York  192261.83
# 3   New York  182901.99
# 5   New York  156991.12
# 8   New York  152211.77
# 15  New York  129917.04
# 17  New York  125370.37
# 19  New York  122776.86
# 21  New York  111313.02
# 24  New York  108552.04
# 27  New York  105008.31
# 29  New York  101004.64
# 31  New York   97483.56
# 35  New York   96479.51
# 38  New York   81229.06
# 43  New York   69758.98
# 45  New York   64926.08
# 48  New York   35673.41

# %% [markdown]
# Looking at what data is missing from the subset i created

# %%
# check for null values
Startup_SS_Ny.isnull().sum()
# Out:
# State     0
# Profit    0
# dtype: int64

# %% [markdown]
# Cardinality

# %%
#check cardinality of features
Startup_SS_Ny.nunique()
# Out:
# State      1
# Profit    17
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(Startup_SS_Ny['State'], Startup_SS_Ny['Profit'])
plt.show()

# %%
# split features and target
X = Startup_SS_Ny.iloc[:, :-1].values
y = Startup_SS_Ny.iloc[:, -1].values

# %%
# split data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=.2, random_state=0)

# %%
y_train.mean()
# Out:
# 108816.95307692306

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
y_mean = y_train.mean()
y_pred_baseline = [y_mean]*len(y_train)
print("Mean apt price:",round(y_mean,2))

print("Baseline R-squared:", round(r2_score(y_train,y_pred_baseline),2))
# Out:
# Mean apt price: 108816.95
# Baseline R-squared: 0.0

# %%
# CREAT A MAP OF THE DATA IN PLOTLY.EXPRESS
import plotly.express as px
fig = px.scatter(Startup_SS_Ny, x="State", y="Profit")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 4
#       2 import plotly.express as px
#       3 fig = px.scatter(Startup_SS_Ny, x="State", y="Profit")
# ----> 4 fig.show()
#
# File c:\Users\estia\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:3390, in BaseFigure.show(self, *args, **kwargs)
#    3357 """
#    3358 Show a figure using either the default renderer(s) or the renderer(s)
#    3359 specified by the renderer argument
#    (...)
#    3386 None
#    3387 """
#    3388 import plotly.io as pio
# -> 3390 return pio.show(self, *args, **kwargs)
#
# File c:\Users\estia\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
# ...
